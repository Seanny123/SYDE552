# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def ref_poisson(rate, t_len, refac=5):
    t = 0
    spikes = []
    x_rand = np.random.uniform
    
    while t < t_len:
        
        t -= np.log(x_rand())/rate
        spikes.append(t)
        t += refac
    return np.array(spikes)

# %%
spk_res = []
for _ in range(50):
    spk_res.append(ref_poisson(25.0/1000.0, 10*1000))

# %%
tmp = spk_res[0]
tmp[tmp < 1000].shape
# Out:
# (26,)

# %%
color_cycle = plt.rcParams['axes.color_cycle']

# plot the spike raster
for z_i, ze in enumerate(list(spk_res)):
    color = [color_cycle[z_i % len(color_cycle)]]
    plt.eventplot(ze[ze < 1000], colors=color, lineoffsets=[1*z_i])
plt.xlim(0, 1000)
plt.ylim(-0.5, 1*len(spk_res))
plt.ylabel("Trial")
plt.xlabel("Time (s)")
plt.title("Raster Plot")
plt.savefig("spike-raster")

# %%
# ISI histogramm
bins = np.arange(0, 505, 10)
isi_res = []
for s_r in spk_res:
    isi_res.append(np.diff(s_r[s_r < 500]))

_ = plt.hist(isi_res, bins=bins, stacked=True)

# %%
# get the firing rate
bins = np.arange(0, 505, 10)
multi_trial_rate = np.zeros((bins.shape[0] - 1, len(spk_res)))
for z_i, s_r in enumerate(spk_res):
    multi_trial_rate[:, z_i] = np.histogram(s_r[s_r < 500], bins=bins)[0]

# %%
plt.plot(bins[:-1], np.mean(multi_trial_rate, axis=1))
plt.title("Multi-Trial Firing Rate")
plt.ylabel("Spikes/s")
plt.xlabel("Time (s)")
plt.savefig("multi-fr")

# %%
coef_var = []

for s_r in spk_res:
    isis = np.diff(s_r)
    coef_var.append(np.std(isis)/np.mean(isis))
    
coef_var = np.array(coef_var)

# %%
plt.plot(coef_var)
print(np.mean(coef_var))
print(np.std(coef_var))
# TODO: Maybe plot the mean and the std deviation on the plot?
# Out:
# 0.882546931742
# 0.0712358930224

# %%
plt.plot(1/coef_var)
print(np.mean(1/coef_var))
print(np.std(1/coef_var))
# Out:
# 1.14001183236
# 0.0862794803166
